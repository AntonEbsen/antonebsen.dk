# %% [markdown]
# # Welcome to the Research Lab
#
# This is an interactive Python environment running directly in your browser (via Pyodide). Use it to reproduce analysis, explore datasets, or verifying findings from my project portfolio.
#
# ## Available Project Analysis
#
# ### 1. Exchange Rate Dynamics (Applied Data Analysis)
# - [Open Analysis Notebook](exchange-rate-analysis.ipynb)
# - **Focus:** Co-movement of DKK inflation and major currency rates (EUR, USD, CNY).
# - **Data:** Pre-loaded samples from Statistics Denmark.
#
# ## Getting Started
# 1. **Double-click** any notebook in the file browser to open it.
# 2. **Run Cells** using `Shift + Enter`.
# 3. **Libraries:** `pandas`, `numpy`, `matplotlib`, and `scipy` are pre-installed.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Environment Ready: Python 3.11 (Pyodide)")
